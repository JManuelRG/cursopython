# %% [markdown]
# Entrada y Salida de Datos
# Ejercicio:
# Crear una calculadora que sume dos números introducidos por el usuario
#
# Comandos input y print
#
# Operadores en Python:
# ![image.png](attachment:image.png)

# %%
# Entrada de datos

"""
Comando input para entrada de datos

Ejercicio: Crear una calculadora que lea dos números y obtenga la suma de ambos
"""

print("Este programa obtiene la suma de dos números.")
#Lectura de números:
num1 = int(input("Introduce el primer número = "))

num2 = int(input("Introduce el segundo número ="))

print(f"La suma de {num1} + {num2} = {num1+num2}")
# Out:
# Este programa obtiene la suma de dos números.
# Introduce el primer número = 7
# Introduce el segundo número =20
# La suma de 7 + 20 = 27
