# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/1.%20Uso%20del%20lenguaje/1.4%20Operadores%20L%C3%B3gicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estructuras Comparativas
#
# #Operadores lógicos
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Devuelven un valor binario de una comparación, son operadores compuestos (trabajan con dos o más comparaciones y devuelven un resultado, de tipo binario)

# %%
# Negación

print(45 == 34) # Falso
not 45 == 34 # Verdadero
# Out:
# False
# True

# %%
# Operador Y
# Solo devuelve verdadero si ambas condiciones se cumplen
# En caso contrario, devuelve el valor Falso

print(4==5 and 5>8)
# Falso y Falso = Falso
# Out:
# False

# %%
print(4==5 and 5<8)
# Falso y Verdadero = Falso
# Out:
# False

# %%
print(5==5 and 5<8)
# V y V = V
# Out:
# True

# %%
# Operador O Lógico
# Devuelve verdadero, mientras una de las comparaciones sea verdadera
(3==3) or (23!=23)
# V o F = V
# Out:
# True
