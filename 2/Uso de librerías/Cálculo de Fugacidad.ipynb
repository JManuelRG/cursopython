# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2/Uso%20de%20librer%C3%ADas/C%C3%A1lculo%20de%20Fugacidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Correlaciones de Pitzer para coeficiente de fugacidad
# ## Video explicación:
#
# https://youtu.be/hx2pBKDBvE8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ejemplo
# ## Determinar la fugacidad del 1-buteno a 200°C y 70 bar

# %%
# Datos
T = 200+273.15 # Kelvin
P = 70 # bar

# %%
# Tabla B1, Smith/Van Ness
w = 0.191
Pc = 40.43 # bar
Tc = 420 # K

# %%
# variables reducidas
Pr = P/Pc
Tr=T/Tc

# %%
# Definir parámetros B° y B'
Bo = 0.083-0.422/Tr**1.6
B1=0.139-0.172/Tr**4.2

print(f"El valor calculado de Bo = {Bo}")
print(f"El valor calculado de B1 = {B1}")
# Out:
# El valor calculado de Bo = -0.26574915540438004
# El valor calculado de B1 = 0.03472497083555391

# %% [markdown]
# # Calcular el coeficiente de fugacidad:
# $$\phi=exp(\frac{Pr}{Tr}) (B^0+wB^1)$$

# %%
import math
phi=math.exp((Pr/Tr)*(Bo+w*B1))

print(f"El valor calculado de coeficiente de fugacidad es {phi}")
# Out:
# El valor calculado de coeficiente de fugacidad es 0.6715037754465176

# %% [markdown]
# # Comparación con el valor calculado por Lee/Kesler
# ## Video explicación
#
# https://www.youtube.com/watch?v=hutI7HAvvRs

# %%
#Comparación con tablas de Lee/Kessler
phi_LK=0.638601

er = abs(phi-phi_LK)/(phi_LK)*100

print(f"el % de error con respecto al valor calculado \ndel coeficiente de fugacidad con correlación de Lee Kessler es")
print(f"{er} %")
# Out:
# el % de error con respecto al valor calculado
# del coeficiente de fugacidad con correlación de Lee Kessler es
# 5.152321315894847 %
