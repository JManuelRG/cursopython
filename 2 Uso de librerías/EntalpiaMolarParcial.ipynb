# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/EntalpiaMolarParcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video Explicación: https://youtu.be/ff5V3TXpHcU

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import *

# %%
# Definir variables independientes
x1 = symbols('x_1')
x1
# Out:
# x_1

# %%
x2 = 1-x1
x2
# Out:
# 1 - x_1

# %%
H = 9*x1*x2+x1
H
# Out:
# 9*x_1*(1 - x_1) + x_1

# %%
H.simplify()
# Out:
# x_1*(10 - 9*x_1)

# %%
# Entalpía molar parcial 1

# %% [markdown]
# # LATEX
# #$\bar{H}_1=(\frac{\partial{H}}{\partial{n_1}})_{P, T, n_2}$

# %%
Hmp1 = H+x2*H.diff(x1)
Hmp1.simplify()
# Out:
# 9*x_1**2 - 18*x_1 + 10

# %%
Hmp1.subs(x1,0.6)
# Out:
# 2.44000000000000

# %%
Hmp2 = H-x1*H.diff(x1)
Hmp2.simplify()
# Out:
# 9*x_1**2

# %%
Hmp2.subs(x1, 0.6)
# Out:
# 3.24000000000000

# %% [markdown]
# # Entalpía Molar Mezcla
# # $$H=9x_1x_2+x_1$$
#
# # Entalpía Molar Parcial 1
# #$$\bar{H_1}=(10x_1-9x_1^2)+x_2(10-18x_1)$$
#
# # Entalpía Molar Parcial 2
# #$$\bar{H_2}=(10x_1-9x_1^2)-x_1(10-18x_1)$$

# %%
import numpy as np

# %%
x1=np.linspace(start=0,stop=1,num=100)
x2=1-x1
Hmezcla=10*x1-9*x1**2
H1mp=10*x1-9*x1**2+(1-x1)*(10-18*x1)
H2mp=10*x1-9*x1**2-x1*(10-18*x1)

# %%
x1

# %%
import matplotlib.pyplot as plt
plt.plot(x1,Hmezcla, label='$H$')
plt.plot(x1,H1mp, label='$\overline{H}_1$')
plt.plot(x1,H2mp, label='$\overline{H}_2$')
plt.plot(x1[0],H1mp[0], 'go', label='$\overline{H}_1^{\infty}$')
plt.plot(x1[99],H2mp[99], 'ro', label='$\overline{H}_2^{\infty}$')
plt.legend()
plt.title('Propiedades de la mezcla')
plt.xlabel('Composición $x_1$')
plt.ylabel('Entalpía (kJ/mol)')
plt.grid()
plt.show()

# %%
# Tabla de Datos
import pandas as pd
# Conversión a DataFrame
df = pd.DataFrame({"x1": x1,
                   "x2": x2,
                   "H (kJ/mol)":Hmezcla,
                   "H1mp (kJ/mol)":H1mp,
                   "H2mp (kJ/mol)":H2mp})

# Resultado
df.head()
# Out:
#          x1        x2  H (kJ/mol)  H1mp (kJ/mol)  H2mp (kJ/mol)
# 0  0.000000  1.000000    0.000000      10.000000       0.000000
# 1  0.010101  0.989899    0.100092       9.819100       0.000918
# 2  0.020202  0.979798    0.198347       9.640037       0.003673
# 3  0.030303  0.969697    0.294766       9.462810       0.008264
# 4  0.040404  0.959596    0.389348       9.287420       0.014692
