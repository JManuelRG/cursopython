# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/Entalp%C3%ADa_Hielo_a_Vapor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Video explicación: https://youtu.be/8y0S9MTUHtg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import *
T=symbols('T')

# %%
print("Cp agua líquida:")
Cpal=75.4e-3 #kJ/molK
display(Cpal)

print("Cp agua vapor")
Cpav=33.46e-3+0.688e-5*T+0.7604e-8*T**2-3.593e-12*T**3
display(Cpav)

print("Cp agua hielo")
cph=2.090*0.018
display(cph) #kJ/(mol K)
# Out:
# Cp agua líquida:
# 0.0754
# Cp agua vapor
# -3.593e-12*T**3 + 7.604e-9*T**2 + 6.88e-6*T + 0.03346
# Cp agua hielo
# 0.037619999999999994

# %%
h1 =-7.96e-3

# %%
h2 = cph*(0--50)
h2
# Out:
# 1.8809999999999998

# %%
h3 = 6.0095

# %%
h4 = Cpal*(100-0)
h4
# Out:
# 7.539999999999999

# %%
h5=40.656

# %%
h6=integrate(Cpav,(T,100,250))
h6
# Out:
# 5.23325053593750

# %%
h7=0

# %%
h1+h2+h3+h4+h5+h6+h7 # entalpía total en kJ/mol
# Out:
# 61.3117905359375
