# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/Perfil_de_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perfil de constante de equilibrio
# # Video explicación: https://youtu.be/lUiME_Nds8E

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
K1=29.3659
T1=298.15

# %%
import numpy as np
T = np.linspace(start=0,
                stop=1000,
                num=1001)

# %%
T
# Out:
# array([   0.,    1.,    2., ...,  998.,  999., 1000.])

# %%
T = T+273.15
T
# Out:
# array([ 273.15,  274.15,  275.15, ..., 1271.15, 1272.15, 1273.15])

# %%
dH= -45792
dG=-8378
R = 8.314
K = K1 * np.exp(dH/R*(1/T1-1/T))

# %%
K
# Out:
# array([1.59269930e+02, 1.47975863e+02, 1.37556196e+02, ...,
#        2.12206187e-05, 2.11484642e-05, 2.10766679e-05])

# %%
import matplotlib.pyplot as plt
plt.plot(T, K)
plt.title('Perfil de K: $C_2H_4+H_2O->CH_3CH_2OH$')
plt.xlabel("T en K")
plt.ylabel("K de equilibrio")
plt.grid()

# %%
import matplotlib.pyplot as plt
plt.plot(1/T, np.log(K))
plt.title('Perfil de K: $C_2H_4+H_2O->CH_3CH_2OH$')
plt.xlabel("1/T en 1/K")
plt.ylabel("ln K de equilibrio")
plt.grid()
