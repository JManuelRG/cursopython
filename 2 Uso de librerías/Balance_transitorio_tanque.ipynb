# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/Balance_transitorio_tanque.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Balance de Masa en estado transitorio
#
# # Video explicación:
# https://youtu.be/sFbndkXVYgo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Gráfico de la función
#
# #$$V(t)=1.2 + 0.05t-0.00125t^2$$

# %%
# prompt: genera un gráfico general de una función usando matplotlib

import numpy as np
t = np.linspace(start=0, stop=60, num=299)
V = 1.2+0.05*t-0.0025/2*t**2

import matplotlib.pyplot as plt
plt.plot(t, V)
plt.xlabel('tiempo (s)')
plt.ylabel('V ($m^3$)')
plt.title('Comportamiento del volumen')
plt.grid()
plt.show()
