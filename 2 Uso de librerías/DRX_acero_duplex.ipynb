# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/DRX_acero_duplex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problema Difracción de Rayos X
#
# # Video Grabado:https://youtu.be/_v-fnKARhEk
#
# # Cursos del Canal: https://linktr.ee/basicosingenieria

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Cálculo de los planos de difracción de austenita
#
# # Ley de Bragg
#
# #$d=\frac{1.54 A}{2sin\theta}$

# %%
# función de distancia interplanar
import math
def dist(angulo):
  angulo = angulo*math.pi/180
  d = 1.54/(2*math.sin(angulo/2))
  print("El valor de la distancia interplanar para un ángulo")
  print(f"2theta = {angulo} rad, es de")
  print(f"d = {d} A")

# %%
dist(43.3)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 0.7557275661135446 rad, es de
# d = 2.087084011571209 A

# %%
# Para austenita:
dist(50.4)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 0.879645943005142 rad, es de
# d = 1.808448685161851 A

# %%
dist(74.1)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 1.293288975727798 rad, es de
# d = 1.2779834075240857 A

# %%
dist(89.9)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 1.5690509975429023 rad, es de
# d = 1.0898959715685659 A

# %%
dist(96)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 1.6755160819145563 rad, es de
# d = 1.0361372017969097 A

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Ferrita
dist(44.7)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 0.7801621756414654 rad, es de
# d = 2.0249121377875934 A

# %%
dist(65)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 1.1344640137963142 rad, es de
# d = 1.433092427461755 A

# %%
dist(82.35)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 1.4372786390173302 rad, es de
# d = 1.169570933710288 A

# %%
dist(99.4)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 1.7348572764823638 rad, es de
# d = 1.00961318310836 A

# %%
dist(116.1)
# Out:
# El valor de la distancia interplanar para un ángulo
# 2theta = 2.0263272615654166 rad, es de
# d = 0.907472869983993 A
