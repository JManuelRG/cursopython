# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/Conducci%C3%B3n_Pared_Plana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulador de la transferencia de calor en una pared plana
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Planteamiento del problema y Solución analítica:
#
# https://www.youtube.com/watch?v=keKFHy0jQls
#
# # Explicación de este simulador:
# https://youtu.be/pZSNiQ3MfI8

# %% [markdown]
# # Variación de temperatura en la pared
#  $$ T(x)=({\frac{T_2-T_1}{L}})x+T_1 $$

# %%
# Variables

T1 = 120 #°C
T2 = 50 #°C
k=1.2 #W/mK
A=15 #m2
L=0.2 #m

# %%
# Declarar función definida por el usuario
def Temp(x):
  return ((T2-T1)/L)*x+T1

# %%
Temp(0)
# Out:
# 120.0

# %%
Temp(L)
# Out:
# 50.0

# %%
#a)
Temp(L/2) #En°C
# Out:
# 85.0

# %% [markdown]
# # b) Transferencia de calor
#
# $$\dot{Q} = kA (T_1-T_2)/L$$

# %%
Q=k*A*(T1-T2)/L
print(Q) #En Watts
# Out:
# 6300.0

# %%
# Perfil de temperatura
import matplotlib.pyplot as plt # Librería para graficar
import numpy as np # Librería para generar vectores

X = np.linspace(0,L,50)

# %%
X
# Out:
# array([0.        , 0.00408163, 0.00816327, 0.0122449 , 0.01632653,
#        0.02040816, 0.0244898 , 0.02857143, 0.03265306, 0.03673469,
#        0.04081633, 0.04489796, 0.04897959, 0.05306122, 0.05714286,
#        0.06122449, 0.06530612, 0.06938776, 0.07346939, 0.07755102,
#        0.08163265, 0.08571429, 0.08979592, 0.09387755, 0.09795918,
#        0.10204082, 0.10612245, 0.11020408, 0.11428571, 0.11836735,
#        0.12244898, 0.12653061, 0.13061224, 0.13469388, 0.13877551,
#        0.14285714, 0.14693878, 0.15102041, 0.15510204, 0.15918367,
#        0.16326531, 0.16734694, 0.17142857, 0.1755102 , 0.17959184,
#        0.18367347, 0.1877551 , 0.19183673, 0.19591837, 0.2       ])

# %%
T = Temp(X)
T
# Out:
# array([120.        , 118.57142857, 117.14285714, 115.71428571,
#        114.28571429, 112.85714286, 111.42857143, 110.        ,
#        108.57142857, 107.14285714, 105.71428571, 104.28571429,
#        102.85714286, 101.42857143, 100.        ,  98.57142857,
#         97.14285714,  95.71428571,  94.28571429,  92.85714286,
#         91.42857143,  90.        ,  88.57142857,  87.14285714,
#         85.71428571,  84.28571429,  82.85714286,  81.42857143,
#         80.        ,  78.57142857,  77.14285714,  75.71428571,
#         74.28571429,  72.85714286,  71.42857143,  70.        ,
#         68.57142857,  67.14285714,  65.71428571,  64.28571429,
#         62.85714286,  61.42857143,  60.        ,  58.57142857,
#         57.14285714,  55.71428571,  54.28571429,  52.85714286,
#         51.42857143,  50.        ])

# %%
#Perfil de temperatura en la pared

plt.plot(X,T, label="T vs x")
plt.legend()
plt.title("Perfil de temperatura")
plt.xlabel("Espesor, m")
plt.ylabel("Temperatura, °C")
plt.grid()
plt.show()
