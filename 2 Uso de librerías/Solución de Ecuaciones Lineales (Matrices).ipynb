# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/Soluci%C3%B3n%20de%20Ecuaciones%20Lineales%20(Matrices).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
A = np.array([[24,6,12],
              [-3,0,1],
              [-4,1,-4]])
print(A)
# Out:
# [[24  6 12]
#  [-3  0  1]
#  [-4  1 -4]]

# %%
b = np.array([156,
              0,
              0])
print(b)
# Out:
# [156   0   0]

# %%
# Solución
X = b*np.linalg.inv(A)
print(X)
# Out:
# [[ 1. -0. -0.]
#  [16.  0.  0.]
#  [ 3.  0. -0.]]

# %%
print("La solución al sistema es:")
print(f"x = {X[0][0]}") 
print(f"y = {X[1][0]}")
print(f"z = {X[2][0]}")
# x = 1
# Out:
# La solución al sistema es:
# x = 0.9999999999999997
# y = 16.0
# z = 3.0

# %%
# solución
from math import ceil
x=ceil(X[0][0])
y=X[1][0]
z=X[2][0]

print(f"1 L de leche cuesta {x} €")
print(f"1 kg de jamón cuesta {y} €")
print(f"1 L de aceite de oliva cuesta {z} €")
# Out:
# 1 L de leche cuesta 1 €
# 1 kg de jamón cuesta 16.0 €
# 1 L de aceite de oliva cuesta 3.0 €

# %%
# Comprobación
# Ecuación 1
print("Ecuación 1: ", 24*x+6*y+12*z) # Debe dar 156

# Ecuación 2
print("Ecuación 2: z = ", 3*x) # Debe dar 3*x = 3

# Ecuación 3
print("Ecuación 3: y = ", 4*z+4*x) # Debe dar 16
# Out:
# Ecuación 1:  156.0
# Ecuación 2: z =  3
# Ecuación 3: y =  16.0
