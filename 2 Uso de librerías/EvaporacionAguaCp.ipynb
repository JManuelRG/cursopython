# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/EvaporacionAguaCp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video Explicación:https://youtu.be/zYKbj0nRdr8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import sympy as sp
T = sp.symbols('T')

# %%
T
# Out:
# T

# %%
A=3.47
B=1.45e-3
C=0
D=0.121e5
Cp = A+B*T+C*T**2+D*T**-2
display(Cp)
# Out:
# 0.00145*T + 3.47 + 12100.0/T**2

# %%
Cp.subs(T,298.15)
# Out:
# 4.03843555755370

# %%
R = 8.314 #J/molK
print(f"Cp(vapor agua) = {Cp.subs(T,400)*R} J/molK")
# Out:
# Cp(vapor agua) = 34.3004462500000 J/molK

# %%
Tsat=90+273.15
T2=130+273.15

# %%
sp.integrate(Cp,(T,Tsat,T2))
# Out:
# 164.328622353276

# %%
Qsens = (50)*(R)/18e-3*sp.integrate(Cp,(T,Tsat,T2))/1000
print(f"Qsens = {Qsens} kJ")
# Out:
# Qsens = 3795.07823956982 kJ

# %%
Qlat = 114125 #kJ

# %%
Qtotal = Qsens + Qlat
print(f"Qtotal = Qsens + Qlat = {Qsens} kJ + {Qlat} kJ = {Qtotal} kJ")
# Out:
# Qtotal = Qsens + Qlat = 3795.07823956982 kJ + 114125 kJ = 117920.078239570 kJ

# %% [markdown]
# # Solución con tablas de vapor:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solución Q= 118098 kJ/kg
