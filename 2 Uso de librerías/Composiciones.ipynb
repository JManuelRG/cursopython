# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/cursopython/blob/main/2%20Uso%20de%20librer%C3%ADas/Composiciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Determinar la composición de la siguiente mezcla a la salida del reactor
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Video Explicación: https://youtu.be/fhvUeieRkEY

# %%
nmet = 80
namon = 120
nma = 50
ndma = 20
ntma =10
nthf = 50
nagua = 170

# %%
comp = [nmet, namon, nma, ndma, ntma, nthf, nagua]

# %%
comp
# Out:
# [80, 120, 50, 20, 10, 50, 170]

# %%
nt = sum(comp)
nt
# Out:
# 500

# %%
import numpy as np
np.array(comp)/nt
# [nmet, namon, nma, ndma, ntma, nthf, nagua]
# Out:
# array([0.16, 0.24, 0.1 , 0.04, 0.02, 0.1 , 0.34])
